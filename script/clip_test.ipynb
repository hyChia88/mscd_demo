# %%
# !pip install git+https://github.com/openai/CLIP.git

# %%
import torch
import clip
from PIL import Image
import os
import glob
from tqdm import tqdm
import matplotlib.pyplot as plt
import shutil
import random
import numpy as np

# %%
# Parameters
# Path to your image dataset
filepath = "/kaggle/input/modern-architecture-100k-small-images/Dataset_128px_128px_Images/Public_Buildings"

# Count all image files in the directory
image_files = glob.glob(os.path.join(filepath, "*.jpg")) + \
              glob.glob(os.path.join(filepath, "*.jpeg")) + \
              glob.glob(os.path.join(filepath, "*.png"))

# Set n_of_scan to the total number of images found
n_of_scan = len(image_files)
print(f"Found {n_of_scan} image files in the directory")

n_of_needs = 1000  

# n_of_scan =  1000  # Number of images to scan
# n_of_needs = 50   # Number of top images to select

# n_of_scan =  100  # Number of images to scan
# n_of_needs = 10   # Number of top images to select

# Load the model
device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)
print(f"Model loaded. Using device: {device}")
